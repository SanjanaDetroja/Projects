# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/Users/dhineshkumar/Downloads/30_yr_stock_market_data.csv')

# %%
data.head()
# Out:
#          Date  Dow Jones (^DJI)  Nasdaq (^IXIC)  S&P500 (^GSPC)  \
# 0  1993-11-29       3677.800049      751.539978      461.899994
# 1  1993-11-30       3683.949951      754.390015      461.790009
# 2  1993-12-01       3697.080078      763.809998      461.890015
# 3  1993-12-02       3702.110107      766.729980      463.109985
# 4  1993-12-03       3704.070068      772.219971      464.890015
#
#    NYSE Composite (^NYA)  Russell 2000 (^RUT)  CBOE Volitility (^VIX)  \
# 0            2697.040039           250.139999                   14.12
# 1            2694.080078           250.410004                   13.76
# 2            2699.159912           252.610001                   13.83
# 3            2705.179932           252.910004                   13.51
# 4            2714.699951           253.860001                   12.69
#
#    DAX Index (^GDAXI)  FTSE 100 (^FTSE)  Hang Seng Index (^HSI)  ...  \
# 0         2052.090088       3135.800049             9012.799805  ...
# ...

# %%
data.shape
# Out:
# (7754, 33)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7754 entries, 0 to 7753
# Data columns (total 33 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Date                            7754 non-null   object
#  1   Dow Jones (^DJI)                7555 non-null   float64
#  2   Nasdaq (^IXIC)                  7555 non-null   float64
#  3   S&P500 (^GSPC)                  7555 non-null   float64
#  4   NYSE Composite (^NYA)           7555 non-null   float64
#  5   Russell 2000 (^RUT)             7555 non-null   float64
#  6   CBOE Volitility (^VIX)          7555 non-null   float64
#  7   DAX Index (^GDAXI)              7604 non-null   float64
#  8   FTSE 100 (^FTSE)                7578 non-null   float64
#  9   Hang Seng Index (^HSI)          7402 non-null   float64
#  10  Cocoa (CC=F)                    5995 non-null   float64
#  11  Coffee (KC=F)                   5992 non-null   float64
# ...

# %%
data.isnull().sum()
# Out:
# Date                                 0
# Dow Jones (^DJI)                   199
# Nasdaq (^IXIC)                     199
# S&P500 (^GSPC)                     199
# NYSE Composite (^NYA)              199
# Russell 2000 (^RUT)                199
# CBOE Volitility (^VIX)             199
# DAX Index (^GDAXI)                 150
# FTSE 100 (^FTSE)                   176
# Hang Seng Index (^HSI)             352
# Cocoa (CC=F)                      1759
# Coffee (KC=F)                     1762
# Corn (ZC=F)                       1908
# Cotton (CT=F)                     1760
# Live Cattle (LE=F)                2306
# Orange Juice (OJ=F)               7192
# Soybeans (ZS=F)                   1916
# Sugar (SB=F)                      1799
# Wheat (ZW=F)                      1920
# Ethanol (EH=F)                    3077
# Heating Oil (HO=F)                1919
# Natural Gas (NG=F)                1916
# Crude Oil-Brent (BZ=F)            3700
# Crude Oil-WTI (CL=F)              1912
# ...

# %%
data.shape
# Out:
# (7754, 33)

# %%
data.head()
# Out:
#          Date  Dow Jones (^DJI)  Nasdaq (^IXIC)  S&P500 (^GSPC)  \
# 0  1993-11-29       3677.800049      751.539978      461.899994
# 1  1993-11-30       3683.949951      754.390015      461.790009
# 2  1993-12-01       3697.080078      763.809998      461.890015
# 3  1993-12-02       3702.110107      766.729980      463.109985
# 4  1993-12-03       3704.070068      772.219971      464.890015
#
#    NYSE Composite (^NYA)  Russell 2000 (^RUT)  CBOE Volitility (^VIX)  \
# 0            2697.040039           250.139999                   14.12
# 1            2694.080078           250.410004                   13.76
# 2            2699.159912           252.610001                   13.83
# 3            2705.179932           252.910004                   13.51
# 4            2714.699951           253.860001                   12.69
#
#    DAX Index (^GDAXI)  FTSE 100 (^FTSE)  Hang Seng Index (^HSI)  ...  \
# 0         2052.090088       3135.800049             9012.799805  ...
# ...

# %%
data.columns
# Out:
# Index(['Date', 'Dow Jones (^DJI)', 'Nasdaq (^IXIC)', 'S&P500 (^GSPC)',
#        'NYSE Composite (^NYA)', 'Russell 2000 (^RUT)',
#        'CBOE Volitility (^VIX)', 'DAX Index (^GDAXI)', 'FTSE 100 (^FTSE)',
#        'Hang Seng Index (^HSI)', 'Cocoa (CC=F)', 'Coffee (KC=F)',
#        'Corn (ZC=F)', 'Cotton (CT=F)', 'Live Cattle (LE=F)',
#        'Orange Juice (OJ=F)', 'Soybeans (ZS=F)', 'Sugar (SB=F)',
#        'Wheat (ZW=F)', 'Ethanol (EH=F)', 'Heating Oil (HO=F)',
#        'Natural Gas (NG=F)', 'Crude Oil-Brent (BZ=F)', 'Crude Oil-WTI (CL=F)',
#        'Copper (HG=F)', 'Gold (GC=F)', 'Palladium (PA=F)', 'Platinum (PL=F)',
#        'Silver (SI=F)', 'Treasury Yield 5 Years (^FVX)',
#        'Treasury Bill 13 Week (^IRX)', 'Treasury Yield 10 Years (^TNX)',
#        'Treasury Yield 30 Years (^TYX)'],
#       dtype='object')

# %%
data['Date'] = pd.to_datetime(data['Date'])

# %%
data['month'] = data['Date'].dt.month

# %%
data['year'] = data['Date'].dt.year

# %%
data['Date'].dt.year.unique()
# Out:
# array([1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003,
#        2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014,
#        2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023])

# %%
len(data['Date'].dt.year.unique().tolist())
# Out:
# 31

# %%
data.head()
# Out:
#         Date  Dow Jones (^DJI)  Nasdaq (^IXIC)  S&P500 (^GSPC)  \
# 0 1993-11-29       3677.800049      751.539978      461.899994
# 1 1993-11-30       3683.949951      754.390015      461.790009
# 2 1993-12-01       3697.080078      763.809998      461.890015
# 3 1993-12-02       3702.110107      766.729980      463.109985
# 4 1993-12-03       3704.070068      772.219971      464.890015
#
#    NYSE Composite (^NYA)  Russell 2000 (^RUT)  CBOE Volitility (^VIX)  \
# 0            2697.040039           250.139999                   14.12
# 1            2694.080078           250.410004                   13.76
# 2            2699.159912           252.610001                   13.83
# 3            2705.179932           252.910004                   13.51
# 4            2714.699951           253.860001                   12.69
#
#    DAX Index (^GDAXI)  FTSE 100 (^FTSE)  Hang Seng Index (^HSI)  ...  \
# 0         2052.090088       3135.800049             9012.799805  ...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7754 entries, 0 to 7753
# Data columns (total 33 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Date                            7754 non-null   datetime64[ns]
#  1   Dow Jones (^DJI)                7555 non-null   float64
#  2   Nasdaq (^IXIC)                  7555 non-null   float64
#  3   S&P500 (^GSPC)                  7555 non-null   float64
#  4   NYSE Composite (^NYA)           7555 non-null   float64
#  5   Russell 2000 (^RUT)             7555 non-null   float64
#  6   CBOE Volitility (^VIX)          7555 non-null   float64
#  7   DAX Index (^GDAXI)              7604 non-null   float64
#  8   FTSE 100 (^FTSE)                7578 non-null   float64
#  9   Hang Seng Index (^HSI)          7402 non-null   float64
#  10  Cocoa (CC=F)                    5995 non-null   float64
#  11  Coffee (KC=F)                   5992 non-null   float64
# ...

# %%
ethanol_data = data.groupby('Ethanol (EH=F)').sum(numeric_only=True)
ethanol_data.drop(columns = ['Cocoa (CC=F)', 'Coffee (KC=F)',
       'Corn (ZC=F)', 'Cotton (CT=F)', 'Live Cattle (LE=F)',
       'Orange Juice (OJ=F)', 'Soybeans (ZS=F)', 'Sugar (SB=F)',
       'Wheat (ZW=F)', 'Heating Oil (HO=F)',
       'Natural Gas (NG=F)', 'Crude Oil-Brent (BZ=F)', 'Crude Oil-WTI (CL=F)',
       'Copper (HG=F)', 'Gold (GC=F)', 'Palladium (PA=F)', 'Platinum (PL=F)',
       'Silver (SI=F)', 'Treasury Yield 5 Years (^FVX)',
       'Treasury Bill 13 Week (^IRX)', 'Treasury Yield 10 Years (^TNX)',
       'Treasury Yield 30 Years (^TYX)'],inplace = True)
ethanol_data
# Out:
#                 Dow Jones (^DJI)  Nasdaq (^IXIC)  S&P500 (^GSPC)  \
# Ethanol (EH=F)
# 0.820               20943.509766     7360.580078     2470.500000
# 0.845               42465.968750    14860.390137     5015.549805
# 0.866               22653.859375     7887.259766     2659.409912
# 0.869               22679.990234     7913.240234     2663.679932
# 0.883               18591.929688     6860.669922     2237.399902
# ...                          ...             ...             ...
# 3.940               11014.549805     2129.949951     1251.540039
# 3.975               10706.139648     2072.469971     1223.689941
# 4.060               10816.919922     2086.000000     1230.040039
# 4.080               22021.570312     4251.619873     2492.329956
# 4.230               10974.839844     2107.060059     1240.119995
#
#                 NYSE Composite (^NYA)  Russell 2000 (^RUT)  \
# Ethanol (EH=F)
# 0.820                     9844.849609          1071.989990
# ...

# %%
data.dropna(inplace = True)

# %%
data.head()
# Out:
#            Date  Dow Jones (^DJI)  Nasdaq (^IXIC)  S&P500 (^GSPC)  \
# 7175 2021-09-07      35100.000000    15374.330078     4520.029785
# 7176 2021-09-08      35031.070312    15286.639648     4514.069824
# 7177 2021-09-09      34879.378906    15248.250000     4493.279785
# 7178 2021-09-10      34607.718750    15115.490234     4458.580078
# 7179 2021-09-13      34869.628906    15105.580078     4468.729980
#
#       NYSE Composite (^NYA)  Russell 2000 (^RUT)  CBOE Volitility (^VIX)  \
# 7175           16801.179688          2275.610107               18.139999
# 7176           16731.039062          2249.729980               17.959999
# 7177           16663.119141          2249.129883               18.799999
# 7178           16563.480469          2227.550049               20.950001
# 7179           16635.390625          2240.780029               19.370001
#
#       DAX Index (^GDAXI)  FTSE 100 (^FTSE)  Hang Seng Index (^HSI)  ...  \
# ...

# %%
gold = data[data['year']==2023]
gold = data.groupby(['year','month'])['Gold (GC=F)'].mean()
gold
# Out:
# year  month
# 1993  11               NaN
#       12               NaN
# 1994  1                NaN
#       2                NaN
#       3                NaN
#                   ...
# 2023  7        1950.764996
#       8        1917.556519
#       9        1912.409998
#       10       1915.568176
#       11       1983.774994
# Name: Gold (GC=F), Length: 361, dtype: float64

# %%
pr_metals= data.groupby(['year','month'])['Gold (GC=F)', 'Palladium (PA=F)', 'Platinum (PL=F)',
       'Silver (SI=F)'].mean()
pr_metals
# Out:
# /var/folders/f1/b1hqr7b52y99mh5q6vg4fpbm0000gn/T/ipykernel_12530/4285826539.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   pr_metals= data.groupby(['year','month'])['Gold (GC=F)', 'Palladium (PA=F)', 'Platinum (PL=F)',
#             Gold (GC=F)  Palladium (PA=F)  Platinum (PL=F)  Silver (SI=F)
# year month
# 2021 9      1768.500000       2006.423519       956.900003      23.004000
#      10     1775.394436       2012.088888      1020.027764      23.471833
#      11     1819.499988       1999.657157      1032.671422      24.186095
#      12     1787.221044       1795.715782       938.015786      22.383474
# 2022 1      1817.547363       2045.315777       996.984211      23.204210
#      2      1867.787483       2328.537521      1047.956245      23.720375
#      3      1950.673902       2559.539116      1046.908694      25.434522
# ...

# %%
pr_metals.plot(figsize=(12, 6), marker='o', linestyle='-')
plt.title('Precious Metals Prices Over Time')
plt.xlabel('Year-Month')
plt.ylabel('Mean Price')
plt.legend(title='Metal')
plt.show()

# %%
energy= data.groupby(['year','month'])['Heating Oil (HO=F)','Natural Gas (NG=F)', 'Crude Oil-Brent (BZ=F)', 'Crude Oil-WTI (CL=F)'].mean()
energy
# Out:
# /var/folders/f1/b1hqr7b52y99mh5q6vg4fpbm0000gn/T/ipykernel_12530/4183741964.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   energy= data.groupby(['year','month'])['Heating Oil (HO=F)','Natural Gas (NG=F)', 'Crude Oil-Brent (BZ=F)', 'Crude Oil-WTI (CL=F)'].mean()
#             Heating Oil (HO=F)  Natural Gas (NG=F)  Crude Oil-Brent (BZ=F)  \
# year month
# 2021 9                2.208582            5.214059               75.390587
#      10               2.520228            5.560389               84.011667
#      11               2.374286            5.120238               80.784285
#      12               2.233653            3.850474               74.159473
# 2022 1                2.621700            4.278632               85.871578
#      2                2.858775            4.353563               94.806250
#      3                3.652222            4.979304              112.283914
# ...

# %%
energy.plot(figsize=(12, 6), marker='o', linestyle='-')
plt.title('Energy Prices Over Time')
plt.xlabel('Year-Month')
plt.ylabel('Mean Price')
plt.legend(title='Energy Type')
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
energy_data = data.groupby(['year', 'month'])[
    'Heating Oil (HO=F)', 'Natural Gas (NG=F)', 'Crude Oil-Brent (BZ=F)', 'Crude Oil-WTI (CL=F)'
].mean()

# Apply Min-Max scaling
scaler = MinMaxScaler()
scaled_energy_data = scaler.fit_transform(energy_data)

# Convert the scaled data back to a DataFrame
scaled_energy_df = pd.DataFrame(scaled_energy_data, columns=energy_data.columns, index=energy_data.index)

# Plot the scaled data
scaled_energy_df.plot(figsize=(12, 6), marker='o', linestyle='-')
plt.title('Scaled Energy Prices Over Time')
plt.xlabel('Year-Month')
plt.ylabel('Scaled Mean Price')
plt.legend(title='Energy Type')
plt.show()
# Out:
# /var/folders/f1/b1hqr7b52y99mh5q6vg4fpbm0000gn/T/ipykernel_12530/2709981592.py:3: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   energy_data = data.groupby(['year', 'month'])[

# %%
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt


# Group by 'year' and 'month', calculate the mean for precious metals
pr_metals = data.groupby(['year', 'month'])[
    'Gold (GC=F)', 'Palladium (PA=F)', 'Platinum (PL=F)', 'Silver (SI=F)'
].mean()

# Apply Min-Max scaling
scaler = MinMaxScaler()
scaled_pr_metals = scaler.fit_transform(pr_metals)

# Convert the scaled data back to a DataFrame
scaled_pr_metals_df = pd.DataFrame(scaled_pr_metals, columns=pr_metals.columns, index=pr_metals.index)

# Plot the scaled data
scaled_pr_metals_df.plot(figsize=(12, 6), marker='o', linestyle='-')
plt.title('Scaled Precious Metals Prices Over Time')
plt.xlabel('Year-Month')
plt.ylabel('Scaled Mean Price')
plt.legend(title='Metal')
plt.show()
# Out:
# /var/folders/f1/b1hqr7b52y99mh5q6vg4fpbm0000gn/T/ipykernel_12530/3112754218.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   pr_metals = data.groupby(['year', 'month'])[

# %%
commudity = data.groupby(['year', 'month'])[
    'Cocoa (CC=F)', 'Coffee (KC=F)',
       'Corn (ZC=F)', 'Cotton (CT=F)', 'Live Cattle (LE=F)',
       'Orange Juice (OJ=F)', 'Soybeans (ZS=F)', 'Sugar (SB=F)',
       'Wheat (ZW=F)'
].mean()
commudity
# Out:
# /var/folders/f1/b1hqr7b52y99mh5q6vg4fpbm0000gn/T/ipykernel_12530/2451354610.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   commudity = data.groupby(['year', 'month'])[
#             Cocoa (CC=F)  Coffee (KC=F)  Corn (ZC=F)  Cotton (CT=F)  \
# year month
# 2021 9       2645.705882     188.867649   519.132353      96.115295
#      10      2632.722222     202.011112   538.805556     109.725556
#      11      2452.666667     221.388096   570.892857     117.882857
#      12      2479.526316     236.149998   589.934211     108.884737
# 2022 1       2542.368421     236.921051   610.434211     119.640526
#      2       2641.750000     247.396876   655.187500     123.776250
#      3       2569.130435     223.508696   747.423913     126.465651
#      4       2563.055556     225.411112   786.013889     140.327222
#      5       2486.894737     219.068421   787.986842     145.764211
# ...

# %%
commodity_data = data.groupby(['year', 'month'])[
    'Cocoa (CC=F)', 'Coffee (KC=F)',
    'Corn (ZC=F)', 'Cotton (CT=F)', 'Live Cattle (LE=F)',
    'Orange Juice (OJ=F)', 'Soybeans (ZS=F)', 'Sugar (SB=F)',
    'Wheat (ZW=F)'
].mean()

# Apply Min-Max scaling
scaler = MinMaxScaler()
scaled_commodity_data = scaler.fit_transform(commodity_data)

# Convert the scaled data back to a DataFrame
scaled_commodity_df = pd.DataFrame(scaled_commodity_data, columns=commodity_data.columns, index=commodity_data.index)

# Plot the scaled data
scaled_commodity_df.plot(figsize=(12, 6), marker='o', linestyle='-')
plt.title('Scaled Commodity Prices Over Time')
plt.xlabel('Year-Month')
plt.ylabel('Scaled Mean Price')
plt.legend(title='Commodity')
plt.show()
# Out:
# /var/folders/f1/b1hqr7b52y99mh5q6vg4fpbm0000gn/T/ipykernel_12530/3155861235.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   commodity_data = data.groupby(['year', 'month'])[

# %%
treasury_yield = data.groupby(['year', 'month'])[
    'Treasury Yield 5 Years (^FVX)','Treasury Bill 13 Week (^IRX)', 'Treasury Yield 10 Years (^TNX)',
       'Treasury Yield 30 Years (^TYX)'
].mean()

# %%
treasury_yield_data = data.groupby(['year', 'month'])[
    'Treasury Yield 5 Years (^FVX)', 'Treasury Bill 13 Week (^IRX)',
    'Treasury Yield 10 Years (^TNX)', 'Treasury Yield 30 Years (^TYX)'
].mean()

# Apply Min-Max scaling
scaler = MinMaxScaler()
scaled_treasury_yield_data = scaler.fit_transform(treasury_yield_data)

# Convert the scaled data back to a DataFrame
scaled_treasury_yield_df = pd.DataFrame(scaled_treasury_yield_data, columns=treasury_yield_data.columns, index=treasury_yield_data.index)

# Plot the scaled data
scaled_treasury_yield_df.plot(figsize=(12, 6), marker='o', linestyle='-')
plt.title('Scaled Treasury Yields Over Time')
plt.xlabel('Year-Month')
plt.ylabel('Scaled Mean Yield')
plt.legend(title='Treasury Yield')
plt.show()
# Out:
# /var/folders/f1/b1hqr7b52y99mh5q6vg4fpbm0000gn/T/ipykernel_12530/2310237356.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   treasury_yield_data = data.groupby(['year', 'month'])[

# %%
metal_share = data.groupby(['Gold (GC=F)', 'Palladium (PA=F)', 'Platinum (PL=F)', 'Silver (SI=F)'])[
    'Dow Jones (^DJI)', 'Nasdaq (^IXIC)', 'S&P500 (^GSPC)',
       'NYSE Composite (^NYA)', 'Russell 2000 (^RUT)',
       'CBOE Volitility (^VIX)', 'DAX Index (^GDAXI)', 'FTSE 100 (^FTSE)',
       'Hang Seng Index (^HSI)'
].mean()

# %%
metal_and_indices = data[['Gold (GC=F)', 'Palladium (PA=F)', 'Platinum (PL=F)', 'Silver (SI=F)',
                          'Dow Jones (^DJI)', 'Nasdaq (^IXIC)', 'S&P500 (^GSPC)',
                          'NYSE Composite (^NYA)', 'Russell 2000 (^RUT)',
                          'CBOE Volatility (^VIX)', 'DAX Index (^GDAXI)', 'FTSE 100 (^FTSE)',
                          'Hang Seng Index (^HSI)']]

# Calculate the correlation matrix
correlation_matrix = metal_and_indices.corr()

# Print or use the correlation matrix as needed
print(correlation_matrix)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/f1/b1hqr7b52y99mh5q6vg4fpbm0000gn/T/ipykernel_12530/3581114419.py in <module>
# ----> 1 metal_and_indices = data[['Gold (GC=F)', 'Palladium (PA=F)', 'Platinum (PL=F)', 'Silver (SI=F)',
#       2                           'Dow Jones (^DJI)', 'Nasdaq (^IXIC)', 'S&P500 (^GSPC)',
#       3                           'NYSE Composite (^NYA)', 'Russell 2000 (^RUT)',
#       4                           'CBOE Volatility (^VIX)', 'DAX Index (^GDAXI)', 'FTSE 100 (^FTSE)',
#       5                           'Hang Seng Index (^HSI)']]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3509             if is_iterator(key):
#    3510                 key = list(key)
# -> 3511             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3512
# ...

# %%
metal_and_indices = data[['Gold (GC=F)', 'Palladium (PA=F)', 'Platinum (PL=F)', 'Silver (SI=F)',
                          'Dow Jones (^DJI)', 'Nasdaq (^IXIC)', 'S&P500 (^GSPC)',
                          'NYSE Composite (^NYA)', 'Russell 2000 (^RUT)',
                          'CBOE Volitility (^VIX)', 'DAX Index (^GDAXI)', 'FTSE 100 (^FTSE)',
                          'Hang Seng Index (^HSI)']]

# Correct the column name for CBOE Volatility
metal_and_indices = metal_and_indices.rename(columns={'CBOE Volitility (^VIX)': 'CBOE Volatility (^VIX)'})

# Calculate the correlation matrix
correlation_matrix = metal_and_indices.corr()

# Print or use the correlation matrix as needed
print(correlation_matrix)
# Out:
#                         Gold (GC=F)  Palladium (PA=F)  Platinum (PL=F)  \
# Gold (GC=F)                1.000000         -0.429868         0.346235
# Palladium (PA=F)          -0.429868          1.000000         0.276553
# Platinum (PL=F)            0.346235          0.276553         1.000000
# Silver (SI=F)              0.775875         -0.081780         0.668343
# Dow Jones (^DJI)           0.369942         -0.129215         0.338802
# Nasdaq (^IXIC)             0.226715         -0.012608         0.069282
# S&P500 (^GSPC)             0.365667         -0.089242         0.126513
# NYSE Composite (^NYA)      0.258706          0.155837         0.368413
# Russell 2000 (^RUT)       -0.131520          0.384818         0.276342
# CBOE Volatility (^VIX)    -0.473524          0.661540        -0.068357
# DAX Index (^GDAXI)         0.596924         -0.540580         0.334596
# FTSE 100 (^FTSE)           0.573802         -0.388205         0.281877
# ...

# %%
import seaborn as sns
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap: Metals vs. Stock Indices')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Select relevant columns
selected_columns = ['Dow Jones (^DJI)', 'Nasdaq (^IXIC)', 'S&P500 (^GSPC)',
                    'NYSE Composite (^NYA)', 'Russell 2000 (^RUT)',
                    'CBOE Volitility (^VIX)', 'DAX Index (^GDAXI)', 'FTSE 100 (^FTSE)',
                    'Hang Seng Index (^HSI)', 'Cocoa (CC=F)', 'Coffee (KC=F)',
                    'Corn (ZC=F)', 'Cotton (CT=F)', 'Live Cattle (LE=F)',
                    'Orange Juice (OJ=F)', 'Soybeans (ZS=F)', 'Sugar (SB=F)',
                    'Wheat (ZW=F)', 'Ethanol (EH=F)', 'Heating Oil (HO=F)',
                    'Natural Gas (NG=F)', 'Crude Oil-Brent (BZ=F)', 'Crude Oil-WTI (CL=F)',
                    'Copper (HG=F)', 'Gold (GC=F)', 'Palladium (PA=F)', 'Platinum (PL=F)',
                    'Silver (SI=F)', 'Treasury Yield 5 Years (^FVX)',
                    'Treasury Bill 13 Week (^IRX)', 'Treasury Yield 10 Years (^TNX)',
                    'Treasury Yield 30 Years (^TYX)']

# Extract selected columns from the DataFrame
selected_data = data[selected_columns]

# Calculate the correlation matrix
correlation_matrix = selected_data.corr()

# Plot the heatmap
plt.figure(figsize=(18, 14))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap: Financial Data')
plt.show()
